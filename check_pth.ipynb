# %%
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# %%
path = '/works/data/BRATS-2018/MICCAI_BraTS_2018_Data_Training/npz_data_128_t1ce_for_ccsdg/train/t1ce'
data = glob(path + '/*')
print(len(data), data[0])
# Out:
# 35340 /works/data/BRATS-2018/MICCAI_BraTS_2018_Data_Training/npz_data_128_t1ce_for_ccsdg/train/t1ce/sample1.npz

# %%
np_data = np.load(data[300])
print(np_data.files)
# Out:
# ['image', 'label']

# %%
label = np_data['label']
print(label.shape)
plt.imshow(label, cmap='gray')
# Out:
# (128, 128)

# %%
# Out:
# [0. 1.]
